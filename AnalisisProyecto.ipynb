# %%
import pandas
data = pandas.read_excel("HECTAREAS POR PLANTACIONES.xlsx")
data
# Out:
#         PERIODO  NÚMERO INCENDIOS FORESTALES  PINO INSIGNE 0-10 AÑOS  \
# 0   1984 - 1985                         5223               2649.4400
# 1   1985 - 1986                         5421               4820.9500
# 2   1986 - 1987                         5195               4433.4200
# 3   1987 - 1988                         5202               3237.8600
# 4   1988 - 1989                         5241               1514.3600
# 5   1989 - 1990                         4114                647.5700
# 6   1990 - 1991                         5194               1556.0500
# 7   1991 - 1992                         4788                339.5600
# 8   1992 - 1993                         6118               1650.9300
# 9   1993 - 1994                         6214               1421.9700
# 10  1994 - 1995                         5356               2608.9500
# 11  1995 - 1996                         5886               2540.7800
# 12  1996 - 1997                         5493               1900.6600
# ...

# %%
data2 = pandas.read_excel("HECTAREAS POR CAUSAS GENERALES.xlsx")
data2.set_index('Anio', inplace=True)
data2 = data2.T
data2
# Out:
# Anio   1.1. FAENAS FORESTALES  1.2. FAENAS AGRÍCOLAS Y PECUARIAS  \
# 2003               750.910000                        4172.490000
# 2004              1099.670000                        2449.420000
# 2005               734.320000                        3939.950000
# 2006              1321.900000                        1716.000000
# 2007              2409.330000                        1294.880000
# 2008              1118.570000                        8581.400000
# 2009              1255.370000                        8325.610000
# 2010               874.670000                        3024.120000
# 2011               589.230000                        3550.670000
# 2012               637.140000                        1591.270000
# 2013               962.790000                        1930.150000
# 2014              4285.160800                        4823.105100
# 2015              2214.285700                        7328.623600
# ...
